# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.stats import uniform, expon, norm, probplot, percentileofscore

# %%
df = pd.read_csv('BlackFriday.csv')
df.dropna(inplace= True)
df.head()
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1   1000001  P00248942      F   0-17          10             A
# 6   1000004  P00184942      M  46-50           7             B
# 13  1000005  P00145042      M  26-35          20             A
# 14  1000006  P00231342      F  51-55           9             A
# 16  1000006   P0096642      F  51-55           9             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                           2               0                   1
# 6                           2               1                   1
# 13                          1               1                   1
# 14                          1               0                   5
# 16                          1               0                   2
#
#     Product_Category_2  Product_Category_3  Purchase
# 1                  6.0                14.0     15200
# 6                  8.0                17.0     19215
# 13                 2.0                 5.0     15665
# 14                 8.0                14.0      5378
# 16                 3.0                 4.0     13055

# %%
#algo errado????

df.Purchase.describe()
# Out:
# count    164278.000000
# mean      11661.001686
# std        5081.553550
# min         185.000000
# 25%        7871.250000
# 50%       11757.000000
# 75%       15627.000000
# max       23959.000000
# Name: Purchase, dtype: float64

# %%
df.Age.value_counts().plot(kind='bar')

# %%
df.Purchase.plot.box()

# %%
df.Product_Category_1.value_counts()
# Out:
# 1     89822
# 5     18697
# 2     16045
# 3     12242
# 8      8937
# 6      8280
# 4      5257
# 11     1937
# 10     1720
# 13     1035
# 12      157
# 15      149
# Name: Product_Category_1, dtype: int64

# %%
pd.crosstab(df['Age'], df['Gender'])
# Out:
# Gender      F      M
# Age
# 0-17     1552   3237
# 18-25    6970  23919
# 26-35   13364  52552
# 36-45    7728  25030
# 46-50    3572   9563
# 51-55    2479   8539
# 55+      1267   4506

# %%
Analise = df.loc[:,['Purchase','Gender','Product_Category_1']]
Analise
# Out:
#         Purchase Gender  Product_Category_1
# 1          15200      F                   1
# 6          19215      M                   1
# 13         15665      M                   1
# 14          5378      F                   5
# 16         13055      F                   2
# 18         11788      M                   1
# 19         19614      M                   1
# 24         11927      M                   1
# 28          5391      M                   5
# 29         16352      F                   2
# 36         12909      F                   2
# 38         15212      F                   1
# 39         15705      F                   1
# 41         18963      F                   1
# 43         16406      F                   2
# 44         12642      F                   6
# 46         11562      F                   1
# 48         19327      F                   1
# 54         12107      M                   1
# 64         11458      M                   1
# 65         11755      F                   1
# 67         15872      M                   1
# 69         15172      M                   1
# 71         10754      F                   3
# 72          2802      F                   4
# 73         19473      F                   1
# 75         19313      F                   1
# 76         15182      F                   1
# 77         15985      F                   2
# 78         16454      F                   2
# ...          ...    ...                 ...
# 537489      9770      M                   2
# 537490     15277      M                   1
# 537495     13115      M                   2
# 537498     11802      M                   1
# 537499     11610      M                   1
# 537507      7604      M                   1
# 537508      4683      M                  11
# 537510     15622      M                   1
# 537515     11466      M                   1
# 537516     15525      M                   1
# 537517      8097      M                   8
# 537519     16469      M                   2
# 537520     15493      M                   1
# 537521      6003      M                  11
# 537523      5905      M                  11
# 537526      3822      M                   1
# 537528     11879      M                   1
# 537529     19217      M                   1
# 537531     10974      M                   3
# 537539     12510      M                   6
# 537542     10036      M                   8
# 537544     11535      M                   1
# 537545      9687      M                   2
# 537546     15515      M                   1
# 537547     11543      M                   1
# 537549     13082      M                   2
# 537551      6863      M                   5
# 537562     11508      M                   1
# 537571     11852      M                   1
# 537573     19196      M                   1
#
# [164278 rows x 3 columns]
